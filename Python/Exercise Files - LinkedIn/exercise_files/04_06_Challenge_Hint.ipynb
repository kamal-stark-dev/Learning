# %% [markdown]
# ## ASCII Art Encoding

# %% [markdown]
# ### Challenge Hints!

# %% [markdown]
# **Hint 1:** While iterating through each character of a string, we can print out when a string has "switched" from one character to another:

# %%
stringVal = 'AAAAABBBBBCCCCC'

prevChar = None
for char in stringVal:
    if char != prevChar:
        print(f'New character is {char}')
    prevChar = char
# Out:
# New character is A
# New character is B
# New character is C

# %% [markdown]
# **Hint 2:** Remember that you can multiply a string by a number!

# %%
'A'*5
# Out:
# 'AAAAA'

# %%
def encodeString(stringVal):
    encodedList = []
    prevChar = stringVal[0]
    count = 0
    for char in stringVal:
        if char != prevChar:
            encodedList.append((prevChar, count))
            count = 0
        prevChar = char
        count += 1
    encodedList.append((prevChar, count))
    return encodedList

def decodeString(encodedList):
    result = ''
    for char, times in encodedList:
        result += char * times
    return result

# %%
art = '''
                               %%%%%%%%%%%%%%%%%%%
                        %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
                    %%%%%%%%                         %%%%%%%%
                %%%%%%%                                   %%%%%%
              %%%%%%                                         %%%%%%
           %%%%%%                                               %%%%%
          %%%%%                                                   %%%%%
        %%%%%                                                       %%%%%
       %%%%                 %%%%%              %%%%%                  %%%%
      %%%%                 %%%%%%%            %%%%%%%                  %%%%
     %%%%                  %%%%%%%            %%%%%%%                   %%%%
    %%%%                   %%%%%%%            %%%%%%%                    %%%%
    %%%%                    %%%%%              %%%%%                     %%%%
   %%%%                                                                   %%%%
   %%%%                                                                   %%%%
   %%%%                                                                   %%%%
   %%%%                                                      %%%%        %%%%
    %%%%       %%%%%%                                        %%%%%       %%%%
    %%%%         %%%%                                       %%%%        %%%%
     %%%%         %%%%                                     %%%%         %%%%
      %%%%         %%%%%                                  %%%%         %%%%
       %%%%%         %%%%%                             %%%%%         %%%%%
        %%%%%          %%%%%%                        %%%%%          %%%%
          %%%%%           %%%%%%%               %%%%%%%           %%%%%
            %%%%%             %%%%%%%%%%%%%%%%%%%%%             %%%%%
              %%%%%%%                                        %%%%%
                 %%%%%%%                                 %%%%%%%
                     %%%%%%%%%                     %%%%%%%%%
                          %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
                                   %%%%%%%%%%%%
'''

# %%
encodedString = encodeString(art)
encodedString
# Out:
# [('\n', 1),
#  (' ', 31),
#  ('%', 19),
#  ('\n', 1),
#  (' ', 24),
#  ('%', 33),
#  ('\n', 1),
#  (' ', 20),
#  ('%', 8),
#  (' ', 25),
#  ('%', 8),
#  ('\n', 1),
#  (' ', 16),
#  ('%', 7),
#  (' ', 35),
#  ('%', 6),
#  ('\n', 1),
#  (' ', 14),
#  ('%', 6),
#  (' ', 41),
#  ('%', 6),
#  ('\n', 1),
#  (' ', 11),
#  ('%', 6),
#  (' ', 47),
#  ('%', 5),
#  ('\n', 1),
#  (' ', 10),
#  ('%', 5),
#  (' ', 51),
#  ('%', 5),
#  ('\n', 1),
#  (' ', 8),
#  ('%', 5),
#  (' ', 55),
#  ('%', 5),
#  ('\n', 1),
#  (' ', 7),
#  ('%', 4),
#  (' ', 17),
#  ('%', 5),
#  (' ', 14),
#  ('%', 5),
#  (' ', 18),
#  ('%', 4),
#  ('\n', 1),
#  (' ', 6),
#  ('%', 4),
#  (' ', 17),
#  ('%', 7),
#  (' ', 12),
#  ('%', 7),
#  (' ', 18),
#  ('%', 4),
#  ('\n', 1),
#  (' ', 5),
#  ('%', 4),
#  (' ', 18),
#  ('%', 7),
#  (' ', 12),
#  ('%', 7),
#  (' ', 19),
#  ('%', 4),
#  ('\n', 1),
#  (' ', 4),
#  ('%', 4),
#  (' ', 19),
#  ('%', 7),
#  (' ', 12),
#  ('%', 7),
#  (' ', 20),
#  ('%', 4),
#  ('\n', 1),
#  (' ', 4),
#  ('%', 4),
#  (' ', 20),
#  ('%', 5),
#  (' ', 14),
#  ('%', 5),
#  (' ', 21),
#  ('%', 4),
#  ('\n', 1),
#  (' ', 3),
#  ('%', 4),
#  (' ', 67),
#  ('%', 4),
#  ('\n', 1),
#  (' ', 3),
#  ('%', 4),
#  (' ', 67),
#  ('%', 4),
#  ('\n', 1),
#  (' ', 3),
#  ('%', 4),
#  (' ', 67),
#  ('%', 4),
#  ('\n', 1),
#  (' ', 3),
#  ('%', 4),
#  (' ', 54),
#  ('%', 4),
#  (' ', 8),
#  ('%', 4),
#  ('\n', 1),
#  (' ', 4),
#  ('%', 4),
#  (' ', 7),
#  ('%', 6),
#  (' ', 40),
#  ('%', 5),
#  (' ', 7),
#  ('%', 4),
#  ('\n', 1),
#  (' ', 4),
#  ('%', 4),
#  (' ', 9),
#  ('%', 4),
#  (' ', 39),
#  ('%', 4),
#  (' ', 8),
#  ('%', 4),
#  ('\n', 1),
#  (' ', 5),
#  ('%', 4),
#  (' ', 9),
#  ('%', 4),
#  (' ', 37),
#  ('%', 4),
#  (' ', 9),
#  ('%', 4),
#  ('\n', 1),
#  (' ', 6),
#  ('%', 4),
#  (' ', 9),
#  ('%', 5),
#  (' ', 34),
#  ('%', 4),
#  (' ', 9),
#  ('%', 4),
#  ('\n', 1),
#  (' ', 7),
#  ('%', 5),
#  (' ', 9),
#  ('%', 5),
#  (' ', 29),
#  ('%', 5),
#  (' ', 9),
#  ('%', 5),
#  ('\n', 1),
#  (' ', 8),
#  ('%', 5),
#  (' ', 10),
#  ('%', 6),
#  (' ', 24),
#  ('%', 5),
#  (' ', 10),
#  ('%', 4),
#  ('\n', 1),
#  (' ', 10),
#  ('%', 5),
#  (' ', 11),
#  ('%', 7),
#  (' ', 15),
#  ('%', 7),
#  (' ', 11),
#  ('%', 5),
#  ('\n', 1),
#  (' ', 12),
#  ('%', 5),
#  (' ', 13),
#  ('%', 21),
#  (' ', 13),
#  ('%', 5),
#  ('\n', 1),
#  (' ', 14),
#  ('%', 7),
#  (' ', 40),
#  ('%', 5),
#  ('\n', 1),
#  (' ', 17),
#  ('%', 7),
#  (' ', 33),
#  ('%', 7),
#  ('\n', 1),
#  (' ', 21),
#  ('%', 9),
#  (' ', 21),
#  ('%', 9),
#  ('\n', 1),
#  (' ', 26),
#  ('%', 29),
#  ('\n', 1),
#  (' ', 35),
#  ('%', 12),
#  ('\n', 1)]

# %%
print(decodeString(encodedString))
# Out:
#                                %%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%                         %%%%%%%%
#                 %%%%%%%                                   %%%%%%
#               %%%%%%                                         %%%%%%
#            %%%%%%                                               %%%%%
#           %%%%%                                                   %%%%%
#         %%%%%                                                       %%%%%
#        %%%%                 %%%%%              %%%%%                  %%%%
#       %%%%                 %%%%%%%            %%%%%%%                  %%%%
#      %%%%                  %%%%%%%            %%%%%%%                   %%%%
#     %%%%                   %%%%%%%            %%%%%%%                    %%%%
#     %%%%                    %%%%%              %%%%%                     %%%%
#    %%%%                                                                   %%%%
#    %%%%                                                                   %%%%
#    %%%%                                                                   %%%%
#    %%%%                                                      %%%%        %%%%
#     %%%%       %%%%%%                                        %%%%%       %%%%
#     %%%%         %%%%                                       %%%%        %%%%
#      %%%%         %%%%                                     %%%%         %%%%
#       %%%%         %%%%%                                  %%%%         %%%%
#        %%%%%         %%%%%                             %%%%%         %%%%%
#         %%%%%          %%%%%%                        %%%%%          %%%%
#           %%%%%           %%%%%%%               %%%%%%%           %%%%%
#             %%%%%             %%%%%%%%%%%%%%%%%%%%%             %%%%%
#               %%%%%%%                                        %%%%%
#                  %%%%%%%                                 %%%%%%%
#                      %%%%%%%%%                     %%%%%%%%%
#                           %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                    %%%%%%%%%%%%

# %%
# haha car go vroom vroom boom boom brrrrrrrrrrr.............
